# %% [markdown]
# # Baseball Case Study

# %% [markdown]
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# **-- Input features-**

# %% [markdown]
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
#
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
#
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
#
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
#
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
#
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
#
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
#
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
#
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
#
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
#
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
#
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
#
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
#
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
#
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
#
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
#
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.

# %% [markdown]
# **-- Output --:** Number of predicted wins (W)

# %% [markdown]
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics

# %% [markdown]
# **For downloading the dataset, use the link given below.**

# %% [markdown]
# # Dataset Link-

# %% [markdown]
# •	https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/baseball.csv

# %% [markdown]
# # Answer:-

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
#Checking every column names 
df.columns.to_list()
# Out:
# ['W',
#  'R',
#  'AB',
#  'H',
#  '2B',
#  '3B',
#  'HR',
#  'BB',
#  'SO',
#  'SB',
#  'RA',
#  'ER',
#  'ERA',
#  'CG',
#  'SHO',
#  'SV',
#  'E']

# %%
#Checking for duplicated row in the Dataset
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Here you can see no duplicate row is present.**

# %%
#Checking the data type of the columns
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# **Here you can see all columns data types are in Integers except ERA column.**

# %%
#Checking the dimension of the dataset
df.shape
# Out:
# (30, 17)

# %% [markdown]
# **Here you can see our dataset has 30 rows and 17 columns.**

# %%
#Checking null values for each columns
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# **Here you can see no null value is present.**

# %%
#Checking info of df DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# **Observation:-**
#
# 1) Here you can see 1 column contains Float values and 16 columns have the integer values.
#
# 2) This dataset takes 4.1 KB memory.
#
# 3) <class 'pandas.core.frame.DataFrame'> indecates that it's the details about the DataFrame.
#
# 4) Here no null value is present in any columns.

# %%
#Lets visualize null value using heatmap
sns.heatmap(df.isnull(),cmap="Paired")
# Out:
# <Axes: >

# %% [markdown]
# **Here you can see no null value is present.**

# %%
#Checking unique values for each columns
df.nunique().to_frame("Unique value count")
# Out:
#      Unique value count
# W                    24
# R                    28
# AB                   29
# H                    29
# 2B                   22
# 3B                   23
# HR                   27
# BB                   29
# SO                   29
# SB                   27
# RA                   30
# ER                   30
# ERA                  30
# CG                    9
# SHO                  12
# SV                   20
# E                    21

# %% [markdown]
# **Observation:-**
#
# You can see our Target column that is "W" here has very low difference with it's value count(30 values) and this column's unique value count(24 values).So cleearly it's a Regression problem.

# %%
#Value counts for each column
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
#
#
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
#
#
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# ...

# %% [markdown]
# **Observation:-**
#
# 1) Here you can see no column has blank value.
#
# 2) Here columns have numeric datatypes so I don't have to use any encoding techniques.

# %%
#Checking description of Dataset
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# **Observation:-**
#
# 1) For columns "R","2B","BB","SO","RA","ER","ERA","SHO" these column's median(50%) values are greater than mean ,that means these columns values are left skewed.
#
# 2) Apart form the column names those are I mentioned above has higher mean value than Midean(50%) that means these column's data has right skewed."SB" column's mean and median is the same that means this column's data is symmetrical.
#
# 3) We can see there is high difference between 75 percentile and Max for "R","AB","3B","HR","SO","SB","RA","ER","ERA","SHO","SV","E" that means these columns might have outliers.

# %% [markdown]
# # Data Visualization:-

# %% [markdown]
# **Bivariate analysis**

# %%
plt.figure(figsize=(25,20))
sns.lmplot(x="W",y="R",data=df)

# %% [markdown]
# **Here you can see our Target column W is slightly positive correlated with "R" column.**

# %%
plt.figure(figsize=(25,20))
sns.lmplot(x="W",y="AB",data=df)

# %% [markdown]
# **"AB" is weakly correlated with our Target column "W".**

# %%
plt.figure(figsize=(25,20))
sns.lmplot(x="W",y="H",data=df)

# %% [markdown]
# **"H" is weakly correlated with our Target column "W".**

# %%
plt.figure(figsize=(25,20))
sns.lmplot(x="W",y="2B",data=df)

# %% [markdown]
# **"2B" is positively correlated with our Target column "W".**

# %%
plt.figure(figsize=(25,20))
sns.lmplot(x="W",y="3B",data=df)

# %% [markdown]
# **"3B" is negatively correlated with our Target column "W".**

# %%
plt.figure(figsize=(25,20))
sns.lmplot(x="W",y="HR",data=df)

# %% [markdown]
# **"HR" is positively correlated with our Target column "W".

# %%
plt.figure(figsize=(25,20))
sns.lmplot(x="W",y="BB",data=df)

# %% [markdown]
# **BB has waek positive correlation with W.**

# %%
plt.figure(figsize=(25,20))
sns.lmplot(x="W",y="SO",data=df)

# %% [markdown]
# **SO is not correlated with W.**

# %%
plt.figure(figsize=(25,20))
sns.lmplot(x="W",y="SB",data=df)

# %% [markdown]
# **SB is not correlated with our Target column W.**

# %%
plt.figure(figsize=(25,20))
sns.lmplot(x="W",y="RA",data=df)

# %% [markdown]
# **RA has strong negative correlation with our Target column W.**

# %%
plt.figure(figsize=(25,20))
sns.lmplot(x="W",y="ER",data=df)

# %% [markdown]
# **ER is negatively correlated to W.**

# %%
plt.figure(figsize=(25,20))
sns.lmplot(x="W",y="ERA",data=df)

# %% [markdown]
# **ERA has a negative correlation with W.**

# %%
plt.figure(figsize=(25,20))
sns.lmplot(x="W",y="CG",data=df)

# %% [markdown]
# **CG is not correlated with W.**

# %%
plt.figure(figsize=(25,20))
sns.lmplot(x="W",y="SHO",data=df)

# %% [markdown]
# **SHO has a weak positive correlation with W.**

# %%
plt.figure(figsize=(25,20))
sns.lmplot(x="W",y="SV",data=df)

# %% [markdown]
# **SV has strong positive correction with W.**

# %%
plt.figure(figsize=(25,20))
sns.lmplot(x="W",y="E",data=df)

# %% [markdown]
# **E is not correlated with our W column.**

# %%
#Analysis of our Target column (W) with all columns using regplot
plt.figure(figsize=(25,20))

plot=1

if plot<=18:
    for i in df.columns:
        if i=="ERA":
            continue
            
        plt.subplot(7,3,plot)
        sns.regplot(x="W",y=i,data=df)
        plt.xlabel("W",fontsize=20)
        plt.ylabel(i,fontsize=20)
        
        plot+=1
    
plt.show()

# %% [markdown]
# **Multivatiate Analysis:-**

# %%
sns.pairplot(df,palette="Dark_2")

# %% [markdown]
# **Here you can see all your column relationship with each other in a single go.**

# %%
list_1=['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO','W']
list_2=['SB', 'RA', 'ER','ERA', 'CG', 'SHO', 'SV', 'E','W']

data1=pd.DataFrame(df[['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO','W']])
data2=pd.DataFrame(df[['SB', 'RA', 'ER','ERA', 'CG', 'SHO', 'SV', 'E','W']])

sns.pairplot(data1,palette="Dark_2")

# %%
sns.pairplot(data2,palette="Dark_2")

# %%
plt.figure(figsize=(20,25))
plot=1

for i in df.columns:
    if plot<=21:
        plt.subplot(7,3,plot)
        sns.distplot(x=df[i])
        plt.xlabel(i)
        
    plot+=1
    
plt.show()
plt.tight_layout()

# %% [markdown]
# **Observation:-**
#
# 1) Here you can see most of the columns are seemed to be normally distributed.
#
# 2) CG,SHO,H columns have right tail skewness.
#
# 3) RA,ER has left tail skewness.
#
# We will try to remove these skewness using different type of transformation in the later part.

# %% [markdown]
# # Checking for outliers

# %%
#I avoide the W column data because this column is my Trarget column
Selected_column=df[['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER','ERA', 'CG', 'SHO', 'SV', 'E']]

#Checking outliers using boxplot
plt.figure(figsize=(20,25),facecolor="r")
plot=1

for i in Selected_column:
    if plot<=21:
    

        plt.subplot(7,3,plot)
        sns.boxplot(x=Selected_column[i])
        plt.xlabel(i,fontsize=15)
    plot+=1
    

plt.show()

# %% [markdown]
# **Observation:-**
#
# 1) Here you can see R,ERA,SHO,SV and E columns have the outliers.
#
# 2) E Column has most of the outliers.
#
# So I can remove these outliers using the either zscore or IQR method.As per my previous experience IQR also remove too much data to remove outliers so here I will use the zscore to remove the outliers.

# %% [markdown]
# # Removing outliers using zscore

# %%
from scipy.stats import zscore
z=np.abs(zscore(Selected_column))
z
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.619078  0.847731  1.663685  1.420173  1.041193  0.787299  1.534902
# 1   0.134432  0.711094  0.970681  0.127403  1.235809  0.243967  0.536592
# 2   0.332906  1.115233  0.151891  1.588795  0.223808  0.723377  1.139144
# 3   1.146419  0.241522  0.401088  0.828122  0.418423  0.883181  1.160536
# 4   0.013270  1.280738  1.984081  0.801892  1.722347  0.403770  0.251360
# 5   3.509647  0.104884  1.361089  1.869832  1.391501  2.185047  1.798742
# 6   1.311430  0.732263  0.116292  0.153633  1.196885  1.545833  1.513510
# 7   0.428681  0.451289  0.596886  1.615025  1.099578  1.705636  0.910958
# 8   0.765626  0.451289  0.365489  0.183611  0.068115  0.107601  0.590073
# 9   1.034489  1.785913  1.628086  1.082929  0.165423  0.084163  0.158660
# 10  1.086415  0.076017  0.275303  0.239818  0.068115  0.267405  0.604334
# 11  0.705622  0.826562  0.721484  0.183611  0.515731  2.121125  0.301276
# ...

# %%
#Finding rows and column location where zscore value is greater than 3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([0], dtype=int64))

# %%
#Checking the outlier's zscore value by giving row and column location
z.iloc[5,0]
# Out:
# 3.5096470447193067

# %% [markdown]
# **Here you can see value is above 3 that means it's and outlier.**

# %% [markdown]
# # Creating outliers free dataset

# %%
new_df=df[(z<3).all(axis=1)]
new_df.shape
# Out:
# (29, 17)

# %%
print("Old DataFrame",df.shape[0])
print("New DataFrame",new_df.shape[0])
# Out:
# Old DataFrame 30
# New DataFrame 29

# %% [markdown]
# **Here you can see just one row is deleted due to outlier.**

# %%
print("Data lost percentage is",((df.shape[0]-new_df.shape[0])/new_df.shape[0])*100)
# Out:
# Data lost percentage is 3.4482758620689653

# %% [markdown]
# **Our acceptable data lost range is 10 so 3% data lost is way below than that percentage and we can afford it.**

# %% [markdown]
# # Checking the data distribution of our newly created outlier free dataset again using the visualization

# %%
plt.figure(figsize=(20,25),facecolor="g")
plot=1

for i in new_df.columns:
    if plot<=21:
        plt.subplot(7,3,plot)
        sns.distplot(x=new_df[i])
        plt.xlabel(i)
        
    plot+=1
    
plt.show()
plt.tight_layout()

# %% [markdown]
# **Observation:-**
#
# So you can see the data distribution are same as our old datasets data distribution so nothing new to mentioned.

# %% [markdown]
# # Checking Skewness:

# %%
new_df.skew().to_frame("Skewness value")
# Out:
#      Skewness value
# W          0.119013
# R         -0.215364
# AB         0.169573
# H          0.783772
# 2B        -0.335304
# 3B         0.090124
# HR         0.450862
# BB         0.151193
# SO        -0.233815
# SB         0.494966
# RA         0.018155
# ER         0.018461
# ERA        0.016693
# CG         0.854980
# SHO        0.526943
# SV         0.627480
# E          0.840271

# %% [markdown]
# **Observation:-**
#
# Here you can see our E,SV,CG and H column's skewness are higher than the our default skewness value that is -0.5 to +0.5.So we have to try to reduce these column's skewness.

# %% [markdown]
# # Reducing skewness:

# %%
#Trying to reduce skewness using cube root method
a=new_df["E"]
b=new_df["SV"]
c=new_df["CG"]
d=new_df["H"]


a=np.cbrt(a)
b=np.cbrt(b)
c=np.cbrt(c)
d=np.cbrt(d)


print("E skewness:",a.skew())
print("SV skewness:",b.skew())
print("CG skewness:",c.skew())
print("H skewness:",d.skew())
# Out:
# E skewness: 0.671747645882412
# SV skewness: 0.2809633925573293
# CG skewness: -1.0139811466535003
# H skewness: 0.7536959466136843

# %% [markdown]
# **Here you can see cbrt can reduce the skewness for only SV column to reduce it's skewness value to fall in acceptable skewness value.**

# %%
#Appling the cbrt on SV column to permanently reduce it's skewness
new_df["SV"]=np.cbrt(new_df["SV"])

# %%
#Checking the skewness again
new_df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.280963
# E      0.840271
# dtype: float64

# %% [markdown]
# **SV column's skewness is reduced.Now I will try log transmission on the leftover column those skewness values are not falling in the acceptable range.**

# %%
#Trying to reduce skewness using log method
a=new_df["E"]
c=new_df["CG"]
d=new_df["H"]


a=np.log(a)
c=np.log(c)
d=np.log(d)


print("E skewness:",a.skew())
print("CG skewness:",c.skew())
print("H skewness:",d.skew())
# Out:
# E skewness: 0.5833075389348484
# CG skewness: nan
# H skewness: 0.7384225982580486

# %% [markdown]
# **Here you can see log is reducing the skewness for H but still it's not in the acceptable range and for E column it worked great but it's 0.58 means it's almost 0.6 So I will try more transformation if I dont's get any tranformation that will do better than this the I will permanently apply log on the E column.**

# %%
#Trying to reduce skewness using sqrt method
a=new_df["E"]
c=new_df["CG"]
d=new_df["H"]


a=np.sqrt(a)
c=np.sqrt(c)
d=np.sqrt(d)


print("E skewness:",a.skew())
print("CG skewness:",c.skew())
print("H skewness:",d.skew())
# Out:
# E skewness: 0.7149657245319976
# CG skewness: -0.2606778075812151
# H skewness: 0.7612737602321705

# %% [markdown]
# **Here you can see the sqrt method worked on CG column so I will apply it permanently on this column:**

# %%
#Appling the sqrt on CG column to permanently reduce it's skewness
new_df["CG"]=np.sqrt(new_df["CG"])

# %%
#Checking the skewness again
new_df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.260678
# SHO    0.526943
# SV     0.280963
# E      0.840271
# dtype: float64

# %% [markdown]
# **You can see CG column skewness is reduced now.I will try PowerTransformer now to remove the skewness of leftover columns.**

# %%
a=new_df["E"]
d=new_df["H"]

#Trying to reduce skewness using PowerTransform
#Using PowerTransformer to reduce skewness 
from sklearn.preprocessing import PowerTransformer
reshape_E=a.values.reshape(-1,1)
reshape_H=d.values.reshape(-1,1)

pt=PowerTransformer("yeo-johnson")  #yeo-johnson method works on both positive and Negative method

#Now fitting the Transfomer
E_transformed=pt.fit_transform(reshape_E)
H_transformed=pt.fit_transform(reshape_H)

#Convert the transformed array back to the DataFrame
a=pd.DataFrame(E_transformed)
d=pd.DataFrame(H_transformed)


print("E skewness:",a.skew())
print("H skewness:",d.skew())
# Out:
# E skewness: 0    0.065585
# dtype: float64
# H skewness: 0    0.0
# dtype: float64

# %% [markdown]
# **Here you can see PowerTransformer reduce my E and H column's skewness,so I will apply it permanently on those columns.**

# %%
#Appling PowerTransformer on E and H column permanently
from sklearn.preprocessing import PowerTransformer
reshape_E=new_df["E"].values.reshape(-1,1)
reshape_H=new_df["H"].values.reshape(-1,1)

pt=PowerTransformer("yeo-johnson")  #yeo-johnson method works on both positive and Negative method

#Now fitting the Transfomer
E_transformed=pt.fit_transform(reshape_E)
H_transformed=pt.fit_transform(reshape_H)

#Convert the transformed array back to the DataFrame
new_df["E"]=pd.DataFrame(E_transformed)
new_df["H"]=pd.DataFrame(H_transformed)

# %%
#Checking the skewness again
new_df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.000000
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.260678
# SHO    0.526943
# SV     0.280963
# E      0.073804
# dtype: float64

# %% [markdown]
# **Here you can see all column's skewness are finally in our acceptable range.**

# %%
#Checking for null value again
new_df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      1
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      1
# dtype: int64

# %% [markdown]
# **Here you can see our E and H column has 1 null value and we have to fill it.I will use median to fill these null value to those respective columns.**

# %%
#Filling null value with median for E and H column
new_df["H"].fillna(new_df["H"].median(),inplace=True)
new_df["E"].fillna(new_df["E"].median(),inplace=True)

# %%
#Checking for null value again
new_df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# **So here you can see there is no null value now.**

# %%
#Checking the distribution agin after reducing the skewness
plt.figure(figsize=(20,25),facecolor="g")
plot=1

for i in new_df.columns:
    if plot<=21:
        plt.subplot(7,3,plot)
        sns.distplot(x=new_df[i])
        plt.xlabel(i)
        
    plot+=1
    
plt.show()
plt.tight_layout()

# %% [markdown]
# **Here you can see after removing the skewness almost every column are look like normally distributed.**

# %% [markdown]
# # Checking Correlation between our Target column and all the Features

# %%
new_df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.390451 -0.085780  0.185226  0.384886 -0.206737  0.245697
# R    0.390451  1.000000  0.438022 -0.058666  0.469293  0.134204  0.586894
# AB  -0.085780  0.438022  1.000000 -0.097033  0.490752  0.445604 -0.064653
# H    0.185226 -0.058666 -0.097033  1.000000  0.201342  0.167512 -0.137266
# 2B   0.384886  0.469293  0.490752  0.201342  1.000000  0.342419 -0.098695
# 3B  -0.206737  0.134204  0.445604  0.167512  0.342419  1.000000 -0.369299
# HR   0.245697  0.586894 -0.064653 -0.137266 -0.098695 -0.369299  1.000000
# BB   0.447513  0.258450 -0.137850  0.000949  0.211243 -0.404852  0.336814
# SO   0.156469  0.081158 -0.111243 -0.245424 -0.096772 -0.196586  0.479914
# SB  -0.169503  0.075323  0.373674 -0.276206  0.194308  0.483818 -0.166072
# RA  -0.823176 -0.013858  0.315499 -0.184747 -0.215196  0.312750 -0.092586
# ER  -0.815308  0.007727  0.309146 -0.157602 -0.224993  0.333731 -0.062094
# ...

# %%
new_df.corr()["W"].sort_values(ascending=False)
# Out:
# W      1.000000
# SV     0.755967
# SHO    0.497526
# BB     0.447513
# R      0.390451
# 2B     0.384886
# HR     0.245697
# H      0.185226
# SO     0.156469
# E      0.129702
# CG    -0.003340
# AB    -0.085780
# SB    -0.169503
# 3B    -0.206737
# ER    -0.815308
# RA    -0.823176
# ERA   -0.826952
# Name: W, dtype: float64

# %% [markdown]
# **Ovservation:-**
#
# *1) Here you can see SV column is highly positive correlation with our Target column W.*
#
# *2) ER,RA,ERA columns has highly negative correlation with our Target column W.*

# %%
#Visualization correlation with heatmap
plt.figure(figsize=(20,15))
sns.heatmap(new_df.corr(),cmap="Paired",linewidths=0.1,fmt=".1g",annot=True)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# # Separating Features and Label

# %%
x=new_df.iloc[:,1:]
y=new_df.iloc[:,0]

# %%
x.head(3)
# Out:
#      R    AB             H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0  724  5575  4.163336e-16  300  42  139  383   973  104  641  601  3.73
# 1  696  5467 -2.498002e-16  277  44  156  439  1264   70  700  653  4.07
# 2  669  5439  0.000000e+00  303  29  141  533  1157   86  640  584  3.67
#
#          CG  SHO        SV         E
# 0  1.414214    8  3.825862 -0.348265
# 1  1.414214   12  3.556893 -0.540820
# 2  3.316625   10  3.361975 -1.326125

# %%
y.tail(3)
# Out:
# 27    79
# 28    74
# 29    68
# Name: W, dtype: int64

# %% [markdown]
# # Feature Scalling with StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=pd.DataFrame(sc.fit_transform(x),columns=x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.959398  0.830084  1.668371  1.556538  1.010845 -0.765863 -1.536359
# 1   0.331147 -0.702831 -0.946914  0.201171  1.208917 -0.181389 -0.495021
# 2  -0.274666 -1.100253  0.033818  1.733325 -0.276617 -0.697101  1.252941
# 3  -1.329231  0.233951 -0.293092 -0.800621 -0.474688 -0.869006 -1.145857
# 4   0.174084  1.255894  1.886312  0.908319  1.704094 -0.353293 -0.197495
# 5   1.856900  0.716535 -0.511033 -0.093474 -1.266972  1.743939  1.643442
# 6   0.712585 -0.447345 -0.293092 -1.625627 -1.167936  1.915843 -0.885522
# 7  -0.835605 -0.447345  1.668371  0.260100  0.020490  0.196801 -0.550807
# 8   1.497899  1.752672  0.469699  1.202964  0.119526 -0.009484  0.230197
# 9   1.565212 -0.078310 -0.620003  0.319029  0.020490  0.368705  0.695081
# 10  1.071586 -0.816380 -1.382794  0.260100 -0.573723  2.362794  0.378960
# 11 -0.454167 -1.412514 -0.402062 -1.802414 -1.068901  0.506228 -0.569402
# ...

# %% [markdown]
# # Variance Inflation Factor(V.I.F)

# %%
#Checking Multi-colinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor
VIF=pd.DataFrame()
VIF["VIF values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
VIF["Features Name"]=x.columns
VIF
# Out:
#      VIF values Features Name
# 0      8.536717             R
# 1     20.976136            AB
# 2      2.314111             H
# 3      5.310946            2B
# 4      4.037201            3B
# 5      9.114701            HR
# 6      3.760759            BB
# 7      2.898944            SO
# 8      2.050046            SB
# 9    287.830645            RA
# 10  3233.748259            ER
# 11  2054.804990           ERA
# 12     4.457200            CG
# 13     4.070262           SHO
# 14    11.796460            SV
# 15     3.089410             E

# %% [markdown]
# **Observation:-**
#
# *1) Our acceptable VIF value range value is below 10.*
#
# *2) Here you can see AB,RA,ER,ERA,SHO columns are above that range.So I will drop that column which has the highest VIF value.So here first I have to delete ER column from our x variable and after that I have to check the VIF value again for rest of the column.Let's see:*

# %%
#Deleting ER column form x or independent variable
x.drop("ER",axis=1,inplace=True)

# %%
x.head(2)
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.668371  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.946914  0.201171  1.208917 -0.181389 -0.495021
#
#          SO        SB        RA       ERA        CG       SHO        SV  \
# 0 -2.727623  0.905953 -0.664514 -0.511388 -0.253549 -0.813262  1.586882
# 1  0.121896 -0.585315  0.154638  0.238952 -0.253549  0.159299  0.270050
#
#           E
# 0 -0.342555
# 1 -0.535113

# %% [markdown]
# **Here you can see ER column is deleted.Now checking my VIF values again for rest of the columns.**

# %%
#Checking Multi-colinearity again after deleting ER column
from statsmodels.stats.outliers_influence import variance_inflation_factor
VIF=pd.DataFrame()
VIF["VIF values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
VIF["Features Name"]=x.columns
VIF
# Out:
#     VIF values Features Name
# 0     4.559325             R
# 1     3.757154            AB
# 2     1.903982             H
# 3     3.820783            2B
# 4     3.580435            3B
# 5     4.971786            HR
# 6     3.641326            BB
# 7     2.797544            SO
# 8     2.017444            SB
# 9   118.783326            RA
# 10  112.498724           ERA
# 11    2.972762            CG
# 12    3.572060           SHO
# 13    3.374101            SV
# 14    1.854704             E

# %% [markdown]
# **Observation:-**
#
# 1) Now you can see after deleting the ER column our VIF values are reduced that means this column had multi colinearity with other columns but for RA and ERA column its sill high ,so again I have to  delete the RA column because it has the higher VIF value and after deleting this I have to check the VIF value again for rest of the column.
#
# Remember I have 15 columns that why I am taking the decission to delete this RA column,if I have less columns then I have to skip the delete RA column decission.

# %%
#Deleting RA column form x or independent variable
x.drop("RA",axis=1,inplace=True)

# %%
x.head(1)
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.668371  1.556538  1.010845 -0.765863 -1.536359
#
#          SO        SB       ERA        CG       SHO        SV         E
# 0 -2.727623  0.905953 -0.511388 -0.253549 -0.813262  1.586882 -0.342555

# %% [markdown]
# **Here you can see RA column is also deleted.Now checking my VIF values again for rest of the columns.**

# %%
#Checking Multi-colinearity again after deleting ER column
from statsmodels.stats.outliers_influence import variance_inflation_factor
VIF=pd.DataFrame()
VIF["VIF values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
VIF["Features Name"]=x.columns
VIF
# Out:
#     VIF values Features Name
# 0     4.527214             R
# 1     3.063854            AB
# 2     1.899958             H
# 3     3.788228            2B
# 4     3.558352            3B
# 5     4.324953            HR
# 6     2.994501            BB
# 7     1.978276            SO
# 8     1.841373            SB
# 9     4.609831           ERA
# 10    2.936459            CG
# 11    2.967003           SHO
# 12    3.013913            SV
# 13    1.682796             E

# %% [markdown]
# **Observation:-**
#
# 1) Now we can see all our column's VIF value is under the acceptable VIF value range.
#
# 2) So I can say RA and ER this two columns are the reason for this multi colinearity.After deleted those columns all columns VIF values are fall under the acceptable VIF value range.

# %% [markdown]
# # Modeling

# %% [markdown]
# # Finding the best random_state

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

MaxAcc=0
MaxRs=0

for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    RFR=RandomForestRegressor()
    RFR.fit(x_train,y_train)
    pred=RFR.predict(x_test)
    Acc=r2_score(y_test,pred)
    
    if Acc>MaxAcc:
        MaxAcc=Acc
        MaxRs=i
        
print("Max Accuracy is",MaxAcc,"in the random state: ",MaxRs)
# Out:
# Max Accuracy is 0.8310797896812357 in the random state:  129

# %% [markdown]
# # Creating train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=MaxRs)

# %%
#Importing necessary algos
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.linear_model import Lasso,Ridge

# %% [markdown]
# **LinearRegression**

# %%
#Testing LinearRegression r2_score with all error metrics
LR=LinearRegression()
LR.fit(x_train,y_train)
predLR=LR.predict(x_test)
print("R2 Score:-",r2_score(y_test,predLR))
print("Mean Squared Error:-",mean_squared_error(y_test,predLR))
print("Mean Absolute Error:-",mean_absolute_error(y_test,predLR))
print("Root Mean Absolute Error:-",np.sqrt(mean_absolute_error(y_test,predLR)))
# Out:
# R2 Score:- 0.2515372235950025
# Mean Squared Error:- 56.23635132346685
# Mean Absolute Error:- 6.883756566171597
# Root Mean Absolute Error:- 2.623691400712286

# %% [markdown]
# **RandomForestRegressor**

# %%
#Testing RandomForestRegressor r2_score with all error metrics
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
predRFR=RFR.predict(x_test)
print("R2 Score:-",r2_score(y_test,predRFR))
print("Mean Squared Error:-",mean_squared_error(y_test,predRFR))
print("Mean Absolute Error:-",mean_absolute_error(y_test,predRFR))
print("Root Mean Absolute Error:-",np.sqrt(mean_absolute_error(y_test,predRFR)))
# Out:
# R2 Score:- 0.8312877094972067
# Mean Squared Error:- 12.676333333333337
# Mean Absolute Error:- 2.7066666666666666
# Root Mean Absolute Error:- 1.6451950239004087

# %% [markdown]
# **ExtraTreesRegressor**

# %%
#Testing ExtraTreesRegressor r2_score with all error metrics
ETR=ExtraTreesRegressor()
ETR.fit(x_train,y_train)
predETR=ETR.predict(x_test)
print("R2 Score:-",r2_score(y_test,predETR))
print("Mean Squared Error:-",mean_squared_error(y_test,predETR))
print("Mean Absolute Error:-",mean_absolute_error(y_test,predETR))
print("Root Mean Absolute Error:-",np.sqrt(mean_absolute_error(y_test,predETR)))
# Out:
# R2 Score:- 0.8094852612553403
# Mean Squared Error:- 14.314477777777775
# Mean Absolute Error:- 3.147777777777778
# Root Mean Absolute Error:- 1.7741977842895018

# %% [markdown]
# **DecisionTreeRegressor**

# %%
#Testing DecisionTreeRegressor r2_score with all error metrics
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
predDTR=DTR.predict(x_test)
print("R2 Score:-",r2_score(y_test,predDTR))
print("Mean Squared Error:-",mean_squared_error(y_test,predDTR))
print("Mean Absolute Error:-",mean_absolute_error(y_test,predDTR))
print("Root Mean Absolute Error:-",np.sqrt(mean_absolute_error(y_test,predDTR)))
# Out:
# R2 Score:- 0.33601708839960576
# Mean Squared Error:- 49.888888888888886
# Mean Absolute Error:- 5.666666666666667
# Root Mean Absolute Error:- 2.3804761428476167

# %% [markdown]
# **KNeighborsRegressor**

# %%
#Testing KNeighborsRegressor r2_score with all error metrics
KNN=KNeighborsRegressor()
KNN.fit(x_train,y_train)
predKNN=KNN.predict(x_test)
print("R2 Score:-",r2_score(y_test,predKNN))
print("Mean Squared Error:-",mean_squared_error(y_test,predKNN))
print("Mean Absolute Error:-",mean_absolute_error(y_test,predKNN))
print("Root Mean Absolute Error:-",np.sqrt(mean_absolute_error(y_test,predKNN)))
# Out:
# R2 Score:- 0.506434439697667
# Mean Squared Error:- 37.08444444444443
# Mean Absolute Error:- 4.799999999999999
# Root Mean Absolute Error:- 2.1908902300206643

# %% [markdown]
# **SVR**

# %%
#Testing SVR r2_score with all error metrics
svr=SVR()
svr.fit(x_train,y_train)
predsvr=svr.predict(x_test)
print("R2 Score:-",r2_score(y_test,predsvr))
print("Mean Squared Error:-",mean_squared_error(y_test,predsvr))
print("Mean Absolute Error:-",mean_absolute_error(y_test,predsvr))
print("Root Mean Absolute Error:-",np.sqrt(mean_absolute_error(y_test,predsvr)))
# Out:
# R2 Score:- 0.07050457005689281
# Mean Squared Error:- 69.83838502016977
# Mean Absolute Error:- 6.591064527676086
# Root Mean Absolute Error:- 2.567306862779766

# %% [markdown]
# **Lasso**

# %%
#Testing Lasso r2_score with all error metrics
Lasso=Lasso()
Lasso.fit(x_train,y_train)
predLasso=Lasso.predict(x_test)
print("R2 Score:-",r2_score(y_test,predLasso))
print("Mean Squared Error:-",mean_squared_error(y_test,predLasso))
print("Mean Absolute Error:-",mean_absolute_error(y_test,predLasso))
print("Root Mean Absolute Error:-",np.sqrt(mean_absolute_error(y_test,predLasso)))
# Out:
# R2 Score:- 0.9409400494400633
# Mean Squared Error:- 4.437516779108337
# Mean Absolute Error:- 1.6498142164826328
# Root Mean Absolute Error:- 1.2844509396947137

# %% [markdown]
# **Ridge**

# %%
#Testing Ridge r2_score with all error metrics
ridge=Ridge()
ridge.fit(x_train,y_train)
predRidge=ridge.predict(x_test)
print("R2 Score:-",r2_score(y_test,predRidge))
print("Mean Squared Error:-",mean_squared_error(y_test,predRidge))
print("Mean Absolute Error:-",mean_absolute_error(y_test,predRidge))
print("Root Mean Absolute Error:-",np.sqrt(mean_absolute_error(y_test,predRidge)))
# Out:
# R2 Score:- 0.785744708074044
# Mean Squared Error:- 16.09824329211566
# Mean Absolute Error:- 3.006553438517839
# Root Mean Absolute Error:- 1.7339415902843553

# %% [markdown]
# **Observation:-**
#
# *Till now Lasso is our best model with 0.9409 r2_score and minimum error metrics score.But we have to cross check it with cross validation (cross_val_score).*

# %% [markdown]
# # Cross Validation

# %% [markdown]
# **In crossvalidation of Regressors we have to use a parameter called scoring and have to put "r2" as it's value.**

# %% [markdown]
# **LinearRegression**

# %%
from sklearn.model_selection import cross_val_score
result=cross_val_score(LR,x,y,scoring="r2")
print(result)
print(result.mean())
print("The differents between R2 Score of LinearRegression with it's cross validation is :-",(r2_score(y_test,predLR)-result.mean())*100)
# Out:
# [ 0.49487572 -1.16700823  0.73014907  0.68946475  0.70642088]
# 0.2907804395181831
# The differents between R2 Score of LinearRegression with it's cross validation is :- -3.9243215923180585

# %% [markdown]
# **RandomForestRegressor**

# %%
result2=cross_val_score(RFR,x,y,scoring="r2")
print(result2)
print(result2.mean())
print("The differents between R2 Score of RandomForestRegressor with it's cross validation is :-",(r2_score(y_test,predRFR)-result2.mean())*100)
# Out:
# [ 0.28562909 -5.03649868  0.44410046  0.36773246  0.81736616]
# -0.6243341037132221
# The differents between R2 Score of RandomForestRegressor with it's cross validation is :- 145.56218132104286

# %% [markdown]
# **ExtraTreesRegressor**

# %%
result3=cross_val_score(ETR,x,y,scoring="r2")
print(result3)
print(result3.mean())
print("The differents between R2 Score of ExtraTreesRegressor with it's cross validation is :-",(r2_score(y_test,predETR)-result3.mean())*100)
# Out:
# [ 0.15678182 -4.67367763  0.52253785  0.27691885  0.76601474]
# -0.5902848740200444
# The differents between R2 Score of ExtraTreesRegressor with it's cross validation is :- 139.97701352753847

# %% [markdown]
# **DecisionTreeRegressor**

# %%
result4=cross_val_score(DTR,x,y,scoring="r2")
print(result4)
print(result4.mean())
print("The differents between R2 Score of DecisionTreeRegressor with it's cross validation is :-",(r2_score(y_test,predDTR)-result4.mean())*100)
# Out:
# [ -1.67954545 -10.07894737  -0.15767461  -1.94098361   0.09787736]
# -2.75185473683318
# The differents between R2 Score of DecisionTreeRegressor with it's cross validation is :- 308.7871825232786

# %% [markdown]
# **KNeighborsRegressor**

# %%
result5=cross_val_score(KNN,x,y,scoring="r2")
print(result5)
print(result5.mean())
print("The differents between R2 Score of KNeighborsRegressor with it's cross validation is :-",(r2_score(y_test,predKNN)-result5.mean())*100)
# Out:
# [-0.10113636 -2.54105263  0.28776244  0.26911475  0.53915094]
# -0.3092321710456089
# The differents between R2 Score of KNeighborsRegressor with it's cross validation is :- 81.5666610743276

# %% [markdown]
# **SVR**

# %%
result6=cross_val_score(svr,x,y,scoring="r2")
print(result6)
print(result6.mean())
print("The differents between R2 Score of SVR with it's cross validation is :-",(r2_score(y_test,predsvr)-result6.mean())*100)
# Out:
# [-0.07327198 -1.09484563 -0.02677434 -0.50893625  0.14713539]
# -0.3113385610545089
# The differents between R2 Score of SVR with it's cross validation is :- 38.18431311114017

# %% [markdown]
# **LASSO**

# %%
result7=cross_val_score(Lasso,x,y,scoring="r2")
print(result7)
print(result7.mean())
print("The differents between R2 Score of Lasso with it's cross validation is :-",(r2_score(y_test,predLasso)-result7.mean())*100)
# Out:
# [ 0.74387259 -0.83940234  0.78164415  0.78777779  0.87941757]
# 0.4706619530272894
# The differents between R2 Score of Lasso with it's cross validation is :- 47.027809641277386

# %% [markdown]
# **RIDGE**

# %%
result8=cross_val_score(ridge,x,y,scoring="r2")
print(result8)
print(result8.mean())
print("The differents between R2 Score of Ridge with it's cross validation is :-",(r2_score(y_test,predRidge)-result8.mean())*100)
# Out:
# [ 0.49723489 -1.17663634  0.67318424  0.92683294  0.79703751]
# 0.3435306461497296
# The differents between R2 Score of Ridge with it's cross validation is :- 44.22140619243143

# %% [markdown]
# **Observation:-**
#
# *1) Based on the difference beteen model's cross validation score with it's R2 score LinearRegression is our best model but it's own R2 score is too low so I can't pick this as my best model.*
#
# *2) Here I picked LASSO as my best model because it's regularization techniques also.*
#
# *3) So lasso is my best model.*

# %% [markdown]
# # Hyper Parameter Tuning

# %%
#Lasso
from sklearn.model_selection import GridSearchCV
parameters={
    "alpha":[1.0,2.25,6.24,4.59],
    "max_iter":[1,4,10,20],
    "random_state":[1,4,10,20],
    "selection":["cyclic","random"],
    "positive":[False, True]
    
}

# %%
GSCV=GridSearchCV(Lasso(),parameters,cv=5)

# %%
GSCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1.0, 2.25, 6.24, 4.59],
#                          'max_iter': [1, 4, 10, 20], 'positive': [False, True],
#                          'random_state': [1, 4, 10, 20],
#                          'selection': ['cyclic', 'random']})

# %%
#Finding the best parameters for Hyper parameter tuning
GSCV.best_params_
# Out:
# {'alpha': 1.0,
#  'max_iter': 1,
#  'positive': False,
#  'random_state': 4,
#  'selection': 'random'}

# %% [markdown]
# # Final Model

# %%
#Creating my final model
model=Lasso(alpha=1.0,max_iter=1,positive=False,random_state=4,selection="random")

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print("R2 Score:-",r2_score(y_test,pred))
print("Mean Squared Error:-",mean_squared_error(y_test,pred))
print("Mean Absolute Error",mean_absolute_error(y_test,pred))
print("Root Mean Squared Error",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 Score:- 0.9046042169079341
# Mean Squared Error:- 7.167638714793989
# Mean Absolute Error 2.252367128628137
# Root Mean Squared Error 2.6772446124315925

# %% [markdown]
# **Observation:-**
#
# *1) Earlier my Lasso model's R2 score was 0.9409 and now it is 0.9046 so you can see my model accuracy is decreased after hyper parameter tuning so in this case I dont have to performed hyperparameter.*

# %% [markdown]
# # Serialization And Deserialization

# %% [markdown]
# **Serialization**

# %%
#Saving the model
import joblib
joblib.dump(model,"Win_prediction.pkl")
# Out:
# ['Win_prediction.pkl']

# %% [markdown]
# **Deserialization**

# %%
#Loading the model again to predict Happiness scores
model=joblib.load('Win_prediction.pkl')

#prediction
prediction=np.round(model.predict(x_test).astype(int))
prediction
# Out:
# array([95, 74, 64, 85, 76, 87, 90, 76, 83])

# %%
#Checking orginal Win score and compare it with our model prediction score
a=np.array(y_test)
Test=pd.DataFrame()
Test["Prediction"]=prediction
Test["Original"]=a
Test
# Out:
#    Prediction  Original
# 0          95        98
# 1          74        76
# 2          64        68
# 3          85        87
# 4          76        76
# 5          87        83
# 6          90        90
# 7          76        74
# 8          83        81

# %% [markdown]
# **Observation:-**
#
# So here you can see my win prediction is very accurate.

# %% [markdown]
# # User Define Function To Predict Win

# %%
def Win_prediction(a):
    a=a.reshape(1,-1)
    result=model.predict(a)
    print("The Number of predicted wins is:-",result)

# %%
user_input=np.array([0.959398,0.830084,1.668371,1.556538,1.010845,-0.765863,-1.536359,-2.727623,0.905953,-0.511388,-0.253549,-0.813262,1.586882,-0.342555])

# %%
Win_prediction(user_input)
# Out:
# The Number of predicted wins is:- [90.83187364]

# %% [markdown]
# # THE END
